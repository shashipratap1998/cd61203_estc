# %% [markdown]
# # CD61203 Class on Python: Pandas, Numpy and Matplotlib (Class Report + Assignment)

# %%
# Date: 18/10/23
# Focus of today's class will be 'matplotlib'
# pandas: python library routinely used for dealing with data
# Problem Statement: Predicting Molecultar Solubility Using Molecular Descriptors
# Dataset: -
# The dataset will contain multiple molecular descriptors for each chemical compound, such as molecular weight, number of
# hydrogen bond donors, etc. We have to use these different parameters for using pandas and matplotlib library.


# Brief Overview of the pandas Library

'''

# Pandas: Fast, Powerful and flexible data manipualtion and analysis library.
It provides data structures like Series and DataFrames for handling and analyzing
structured data.

Relevance?
- Data Wrangling: Involves cleaning and processing unorganized data.
- Exploratory Data Analysis (EDA)

Why to use Pandas?: Easy, Flexible, Performance and Communinty Support.
- Also, it hase intuitive and easy syntax. This makes it accessible for new users.
- Comprehensive documentation. Most Problems have already been solved.

'''

'''

Data Structures:
- Series: 1D labeled array capable of holding any data type.
- DataFrame: 2D labeled data structure with columns that can be of different types.
- Functionalities: It offers various functionalities to perform tasks ranging from data cleaning, transformation, and visualization
  to more complex operations like aggregation and reshaping.

'''

# Data Inspection and Summary Statistics


'''
Languge Formats: Markup and Markdown
Markdown format of languages: More recent then LaTeX, more like Vim. The 'text' part in Google Colab is also in this format!.

Example # HEADING will give you first level heading

'''

# Step 1: Import the pandas, numpy and matplotlib libraries
# Syntax: -
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Basic Data Structures in Pandas: -

'''

1. Series:
Definition: A Pandas Series is essentially a one-dimensional array that can hold any data.... It comes with an index, which allows
for both positional and label-based indexing.

- A Pandas Series is essentially a one-dimensional array that can hold any data type. It comes with an index, which allows for both
  positional and label-based indexing.

   # Syntax: pd.Series(data) #

'''
# a. Creation of a Pandas Series: Your can create a Series from a list, dictionary
#     or Numpy Array
# a. From a list
# Step 2: Use the above mentioned syntax: -
# From a List
data = [1, 2, 3, 4, 'a'] # here data is a list
ds = pd.Series(data)
ds
'''
The pd.Series is able to detect the datatype.
For example when I give data = [1, 2, 3, 4] and data = [1, 2, 3, 4, 'a'] it is able to differentiate.
'''

# b. From a Dictionary: s = pd.Series({'a': 1, 'b': 2, 'c': 3})
s = pd.Series({'a': 1, 'b': 2, 'c': 3})
s
# So a,b,c became the indices that we have set.

# c. From a NumPy Array
data = np.array([1, 2, 3])
print("The data as a numpy array is :", data)
s = pd.Series(np.array([1, 2, 3]))
s
# Out:
# The data as a numpy array is : [1 2 3]
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
'''
DataFrame

Definition: A Pandas DataFrame is a 2D table with labeled axes (rows and columns). Each column can have its own data type, and
you can perform operations much like you would in a SQL table or an Excel spreadsheet.

# Syntax: pd.DataFrame(data, columns=columns, index=index)

Creation of a Pandas DataFrame
DataFrames can be created from lists, dictionaries, Series, and even other DataFrames.


'''
# 1. From a List of Lists
df = pd.DataFrame([[1, 'a'], [2, 'b'], [3, 'c']], columns=['Number', 'Letter'])
df
# Out:
#    Number Letter
# 0       1      a
# 1       2      b
# 2       3      c

# %%
# 2, From a dictionary
df = pd.DataFrame({'Number': [1, 2, 3], 'Letter': ['a', 'b', 'c']})
df
# Out:
#    Number Letter
# 0       1      a
# 1       2      b
# 2       3      c

# %%
# 3. From a Series
s1 = pd.Series([1, 2, 3])
s2 = pd.Series(['a', 'b', 'c'])
df = pd.DataFrame({'Number': s1, 'Letter': s2})
df
# Out:
#    Number Letter
# 0       1      a
# 1       2      b
# 2       3      c

# %% [markdown]
# ## Data Import-Export

# %%
'''
# Writing data
How to write a Pandas DataFrame back to a CSV file
Function: to_csv
Syntax: DataFrame.to_csv('file_path)

'''
# Create a simple DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'c']})

# Write DataFrame to a CSV file
df.to_csv('output.csv', index=False) # Syntax!
# !ls output.csv # To the mentioned file.

# Note: the file is only availabe till the session is active.
# So, don't forget to export the important exported file
# Out:
# output.csv

# %% [markdown]
# # Ques: Create a dataframe of Roll no and Names.

# %%
df = pd.DataFrame({'Roll_Number':['23EC91R02','23AG61R19', '23EC91R06', '23MM91R01', '23CY91R02'],'Name':['Abinas Chopdar','Shashi Pratap', 'Sansuma Baro', 'Sanchita Mondal', 'Priyabrata Dash']})
df
# Out:
#   Roll_Number             Name
# 0   23EC91R02   Abinas Chopdar
# 1   23AG61R19    Shashi Pratap
# 2   23EC91R06     Sansuma Baro
# 3   23MM91R01  Sanchita Mondal
# 4   23CY91R02  Priyabrata Dash

# %% [markdown]
# #*Molecular Property Data*

# %%
url = "https://raw.githubusercontent.com/GLambard/Molecules_Dataset_Collection/master/latest/ESOL_delaney-processed.csv"
df = pd.read_csv(url, index_col=0) # Read the CSV file.
df
# The file contains index column, so we add index_column = 0
# By default, it will show the first 5 and last 5 rows.
# This is better functionality than excel.
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Amigdalin                                           -0.974
# 1           Fenfuram                                           -2.885
# 2             citral                                           -2.579
# 3             Picene                                           -6.618
# 4          Thiophene                                           -2.232
# ...              ...                                              ...
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...

# %% [markdown]
#   Where: -
#
#
#
# Compound ID:
#
#     Description: A unique identifier for each chemical compound.
#     Type: Categorical/String
#
# ESOL predicted log solubility in mols per litre:
#
#     Description: The predicted solubility of the compound in mols per litre, computed using the ESOL model.
#     Type: Numerical/Float
#
# Minimum Degree:
#
#     Description: The minimum degree (number of edges connected to a node) in the molecular graph representation of the compound.
#     Type: Numerical/Integer
#
# Molecular Weight:
#
#     Description: The molecular weight of the compound, usually in g/mol.
#     Type: Numerical/Float
#
# Number of H-Bond Donors:
#
#     Description: The number of atoms in the compound that can act as hydrogen bond donors.
#     Type: Numerical/Integer
#
# Number of Rings:
#
#     Description: The number of ring structures in the compound.
#     Type: Numerical/Integer
#
# Number of Rotatable Bonds:
#
#     Description: The number of bonds in the molecule that are capable of rotation.
#     Type: Numerical/Integer
#
# Polar Surface Area:
#
#     Description: The surface area of the molecule that is polar, usually measured in square angstroms (A˚2A˚2).
#     Type: Numerical/Float
#
# Measured log solubility in mols per litre:
#
#     Description: The experimentally measured solubility of the compound in mols per litre, usually obtained through lab experiments.
#     Type: Numerical/Float
#
# Smiles:
#
#     Description: Simplified Molecular Input Line Entry System (SMILES) notation, representing the structural formula of the compound.
#     Type: Categorical/String
#
# ## ESOL model
# The ESOL (Estimated SOLubility) model is an empirical model designed to predict the aqueous solubility of organic compounds. It was developed by John S. Delaney and published in a 2004 paper titled "ESOL: Estimating Aqueous Solubility Directly from Molecular Structure". The model uses a set of molecular descriptors, such as molecular weight, number of atoms, and polar surface area, to estimate the log solubility (log⁡SlogS) of a compound in water.
#
# The ESOL model is relatively simple and interpretable compared to more complex machine learning models. It is often used as a baseline or comparative standard in solubility prediction tasks. The model is particularly useful for screening large compound libraries in drug discovery and other chemical engineering applications, where quick and reasonable solubility estimates are needed.

# %%
df.shape # Rows x Cols
# Out:
# (1128, 10)

# %%
df.columns # Give the name of the columns
# Out:
# Index(['Compound ID', 'ESOL predicted log solubility in mols per litre',
#        'Minimum Degree', 'Molecular Weight', 'Number of H-Bond Donors',
#        'Number of Rings', 'Number of Rotatable Bonds', 'Polar Surface Area',
#        'measured log solubility in mols per litre', 'smiles'],
#       dtype='object')

# %%
df.head() # First 5 elements
# Out:
#   Compound ID  ESOL predicted log solubility in mols per litre  \
# 0   Amigdalin                                           -0.974
# 1    Fenfuram                                           -2.885
# 2      citral                                           -2.579
# 3      Picene                                           -6.618
# 4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
#    Number of Rotatable Bonds  Polar Surface Area  \
# 0                          7              202.32
# ...

# %%
df.tail() # Last 5 elements
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# 1123               1           197.381                        0
# 1124               1           219.266                        1
# 1125               1           246.359                        0
# 1126               1            72.151                        0
# 1127               1           365.964                        0
#
#       Number of Rings  Number of Rotatable Bonds  Polar Surface Area  \
# 1123                0                          0                0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1128 entries, 0 to 1127
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Compound ID                                      1128 non-null   object
#  1   ESOL predicted log solubility in mols per litre  1128 non-null   float64
#  2   Minimum Degree                                   1128 non-null   int64
#  3   Molecular Weight                                 1128 non-null   float64
#  4   Number of H-Bond Donors                          1128 non-null   int64
#  5   Number of Rings                                  1128 non-null   int64
#  6   Number of Rotatable Bonds                        1128 non-null   int64
#  7   Polar Surface Area                               1128 non-null   float64
#  8   measured log solubility in mols per litre        1128 non-null   float64
# ...

# %%
df.describe()
# Out:
#        ESOL predicted log solubility in mols per litre  Minimum Degree  \
# count                                      1128.000000     1128.000000
# mean                                         -2.988192        1.058511
# std                                           1.683220        0.238560
# min                                          -9.702000        0.000000
# 25%                                          -3.948250        1.000000
# 50%                                          -2.870000        1.000000
# 75%                                          -1.843750        1.000000
# max                                           1.091000        2.000000
#
#        Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# count       1128.000000              1128.000000      1128.000000
# mean         203.937074                 0.701241         1.390957
# std          102.738077                 1.089727         1.318286
# ...

# %%
df.mode()
# Out:
#                          Compound ID  \
# 0          1,1,1,2-Tetrachloroethane
# 1              1,1,1-Trichloroethane
# 2          1,1,2,2-Tetrachloroethane
# 3              1,1,2-Trichloroethane
# 4     1,1,2-Trichlorotrifluoroethane
# ...                              ...
# 1123                       triforine
# 1124                      tubercidin
# 1125                          uracil
# 1126                       uric acid
# 1127                     vamidothion
#
#       ESOL predicted log solubility in mols per litre  Minimum Degree  \
# 0                                              -6.007             1.0
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# ...                                               ...             ...
# ...

# %%
# set Compound id as index
df.set_index('Compound ID', inplace=True)
df
# Out:
#                 ESOL predicted log solubility in mols per litre  \
# Compound ID
# Amigdalin                                                -0.974
# Fenfuram                                                 -2.885
# citral                                                   -2.579
# Picene                                                   -6.618
# Thiophene                                                -2.232
# ...                                                         ...
# halothane                                                -2.608
# Oxamyl                                                   -0.908
# Thiometon                                                -3.323
# 2-Methylbutane                                           -2.245
# Stirofos                                                 -4.320
#
#                 Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# Compound ID
# Amigdalin                    1           457.432                        7
# ...

# %%
'''
Row and Column Selection using iloc[] and loc[].

The loc[] method allows you to select rows and columns from a DataFrame based on their labels.
# Syntax: `DataFrame.loc[<row_labels>, <column_labels>]` #

-- Features

- Label-based: Uses the explicit index and column names for selection.

- Sliceable: Allows slicing of rows and columns using their labels.

- Boolean Masking: Can be used with boolean conditions to filter data.

Examples

- Selecting a Single Row by Index Label


'''
df.loc['Oxamyl']
# Out:
# ESOL predicted log solubility in mols per litre                       -0.908
# Minimum Degree                                                             1
# Molecular Weight                                                     219.266
# Number of H-Bond Donors                                                    1
# Number of Rings                                                            0
# Number of Rotatable Bonds                                                  1
# Polar Surface Area                                                      71.0
# measured log solubility in mols per litre                              0.106
# smiles                                             CNC(=O)ON=C(SC)C(=O)N(C)C
# Name: Oxamyl, dtype: object

# %%
# OR
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[1:3, ['Compound ID', 'smiles']] # Selecting specific Columns with Rows
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e416bb7f31f1> in <cell line: 1>()
# ----> 1 df.loc[1:3, ['Compound ID', 'smiles']] # Selecting specific Columns with Rows
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
df[df['Number of Rings']>5]  # Conditional Selection
# Out:
#                                                    ESOL predicted log solubility in mols per litre  \
# Compound ID
# Diosgenin                                                                                   -5.681
# Etoposide (148-167,25mg/ml)                                                                 -3.292
# Kepone                                                                                      -5.112
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)                                           -5.312
# Digitoxin                                                                                   -6.114
# Benzo[ghi]perylene                                                                          -6.446
# Coronene                                                                                    -6.885
# norbormide                                                                                  -4.238
# ...

# %%
# Apply 2 conditions together
df[(df['Number of Rings']>5) & (df['Minimum Degree']==2)]
# Out:
#                     ESOL predicted log solubility in mols per litre  \
# Compound ID
# Benzo[ghi]perylene                                           -6.446
# Coronene                                                     -6.885
#
#                     Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# Compound ID
# Benzo[ghi]perylene               2           276.338                        0
# Coronene                         2           300.360                        0
#
#                     Number of Rings  Number of Rotatable Bonds  \
# Compound ID
# Benzo[ghi]perylene                6                          0
# Coronene                          7                          0
#
#                     Polar Surface Area  \
# Compound ID
# Benzo[ghi]perylene                 0.0
# Coronene                           0.0
#
#                     measured log solubility in mols per litre  \
# Compound ID
# Benzo[ghi]perylene                                     -9.018
# ...

# %%
# Max Molecular Weight
df[(df["Molecular Weight"])==(df['Molecular Weight'].max())]
# Out:
#                                                    ESOL predicted log solubility in mols per litre  \
# Compound ID
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)                                           -5.312
#
#                                                    Minimum Degree  \
# Compound ID
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)               1
#
#                                                    Molecular Weight  \
# Compound ID
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)           780.949
#
#                                                    Number of H-Bond Donors  \
# Compound ID
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)                        6
#
#                                                    Number of Rings  \
# Compound ID
# Digoxin (L1=41,8mg/mL, L2=68,2mg/mL, Z=40,1mg/mL)                8
#
#                                                    Number of Rotatable Bonds  \
# Compound ID
# ...

# %%
# Import the library
import matplotlib.pyplot as plt

# %%
# Matplotlib (Mathematical Ploting Library)
df.plot('Molecular Weight', 'measured log solubility in mols per litre', kind='scatter')
# Out:
# <Axes: xlabel='Molecular Weight', ylabel='measured log solubility in mols per litre'>

# %%
df['Molecular Weight'].plot(kind='hist', edgecolor='black', bins=20)

plt.xlabel('Molecular Weight')
plt.ylabel('Frequency')
plt.title('Histogram of Molecular Weight')
plt.show()

# %%
#plt.plot.scatter("Molecular Weight","measured log solubility in mols per litre") #kind=scatter
import numpy as np
a=np.array(list(df["Molecular Weight"]))
b=np.array(list(df["measured log solubility in mols per litre"]))
plt.plot(a,b,'o')
m,c = np.polyfit(a,b,1)
plt.plot(a,m*a+c)

# %%
import seaborn as sns
from scipy import stats

# Assuming you already have 'df' loaded with your data

# Extract the columns of interest
x = df['ESOL predicted log solubility in mols per litre']
y = df['measured log solubility in mols per litre']

# Create a scatter plot
sns.scatterplot(x=x, y=y)

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Calculate R-squared value
r_squared = r_value**2

# Plot the regression line
plt.plot(x, slope * x + intercept, color='red', label=f'Regression Line (R² = {r_squared:.2f})')

# Add labels and a legend
plt.xlabel('ESOL predicted log solubility')
plt.ylabel('Measured log solubility')
plt.legend()

# Show the plot
plt.show()

# %%
# Extract the columns of interest
molecular_weight = df['Molecular Weight']
polar_surface_area = df['Polar Surface Area']

# Create a scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
plt.scatter(molecular_weight, polar_surface_area, alpha=0.5)  # 'alpha' for transparency

# Add labels and a title
plt.xlabel('Molecular Weight')
plt.ylabel('Polar Surface Area')
plt.title('Scatter Plot: Molecular Weight vs Polar Surface Area')

# Show the plot
plt.grid(True)  # Optional: Add a grid
plt.show()

# %%
# Extract the 'Polar Surface Area' column
polar_surface_area = df['Polar Surface Area']

# Create a histogram for Polar Surface Area
plt.figure(figsize=(8, 6))
plt.hist(polar_surface_area, bins=20, color='green', alpha=0.7)
plt.xlabel('Polar Surface Area (Å²)')
plt.ylabel('Frequency')
plt.title('Histogram of Polar Surface Area')
plt.grid(True)
plt.show()

# %%
# Extract the 'Molecular Weight' column
molecular_weight = df['Molecular Weight']

# Create a histogram for Molecular Weight
plt.figure(figsize=(8, 6))
plt.hist(molecular_weight, bins=20, color='blue', alpha=0.7)
plt.xlabel('Molecular Weight (g/mol)')
plt.ylabel('Frequency')
plt.title('Histogram of Molecular Weight')
plt.grid(True)
plt.show()
